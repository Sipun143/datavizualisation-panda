# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/content/HRDataset_v14.csv")

# %%
df.head(10)
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
# 5         Anderson, Linda    10002          0                0         0
# 6           Andreola, Colby  10194          0                0         0
# 7               Athwal, Sam  10062          0                4         1
# 8          Bachiochi, Linda  10114          0                0         0
# 9        Bacong, Alejandro   10250          0                2         1
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# ...

# %%
df.describe(include="all")
# Out:
#               Employee_Name         EmpID   MarriedID  MaritalStatusID  \
# count                   311    311.000000  311.000000       311.000000
# unique                  311           NaN         NaN              NaN
# top     Adinolfi, Wilson  K           NaN         NaN              NaN
# freq                      1           NaN         NaN              NaN
# mean                    NaN  10156.000000    0.398714         0.810289
# std                     NaN     89.922189    0.490423         0.943239
# min                     NaN  10001.000000    0.000000         0.000000
# 25%                     NaN  10078.500000    0.000000         0.000000
# 50%                     NaN  10156.000000    0.000000         1.000000
# 75%                     NaN  10233.500000    1.000000         1.000000
# max                     NaN  10311.000000    1.000000         4.000000
#
#           GenderID  EmpStatusID      DeptID  PerfScoreID  \
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'EmpID'}>,
#         <Axes: title={'center': 'MarriedID'}>,
#         <Axes: title={'center': 'MaritalStatusID'}>,
#         <Axes: title={'center': 'GenderID'}>],
#        [<Axes: title={'center': 'EmpStatusID'}>,
#         <Axes: title={'center': 'DeptID'}>,
#         <Axes: title={'center': 'PerfScoreID'}>,
#         <Axes: title={'center': 'FromDiversityJobFairID'}>],
#        [<Axes: title={'center': 'Salary'}>,
#         <Axes: title={'center': 'Termd'}>,
#         <Axes: title={'center': 'PositionID'}>,
#         <Axes: title={'center': 'Zip'}>],
#        [<Axes: title={'center': 'ManagerID'}>,
#         <Axes: title={'center': 'EngagementSurvey'}>,
#         <Axes: title={'center': 'EmpSatisfaction'}>,
#         <Axes: title={'center': 'SpecialProjectsCount'}>],
#        [<Axes: title={'center': 'DaysLateLast30'}>,
#         <Axes: title={'center': 'Absences'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
import seaborn as sns
sns.pairplot(df)

# %%
import seaborn as sns

sns.boxplot(x="PerformanceScore", y="ManagerID", data=df)
#to know about the perfomance of employees under which manager
# Out:
# <Axes: xlabel='PerformanceScore', ylabel='ManagerID'>

# %%
sns.barplot(x=df['Employee_Name'].head(5),y=df['Salary'],data=df)
# To know 10 employees who take highest ammount of salary
# Out:
# <Axes: xlabel='Employee_Name', ylabel='Salary'>

# %%
 sns.scatterplot(x=df['EmpID'].head(5),y="Salary",data=df)
 
plt.show()
#To know 5  employee ID  who take highest ammount of salary

# %% [markdown]
# 2nd data set

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import csv
df2 = pd.read_csv("D:\Airbnb Dataset 19.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-4854e86275a0> in <cell line: 2>()
#       1 import csv
# ----> 2 df2 = pd.read_csv("D:\Airbnb Dataset 19.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
#this file doesn`t open
